# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.dpi'] = 500
matplotlib.rcParams['text.usetex'] = False
from scipy import signal
from scipy import integrate

from scipy import constants

# %%
h = constants.h
c = constants.c
k_B = constants.Boltzmann

# %%
Ts = [1700, 1500, 1300, 1100]
λs = np.linspace(0.5*1e-6, 5.5*1e-6,1000)

# %%
def fmt(x):
    s = f"{x:.1f}"
    if s.endswith("0"):
        s = f"{x:.0f}"
    return rf"{s} " if plt.rcParams["text.usetex"] else f"{s} K"

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 5))
ax.set_xlim([0, 6e-6])
ax.grid()
ax.axes.yaxis.set_ticks([])
for T in Ts:
    ax.plot(λs, Plank(λs, T),label=f"{T}K")
ax.set_xlabel(r'$\lambda(\mathrm{m})$',fontsize=18)
ax.set_ylabel(r'$M_{\lambda}$',fontsize=18)
ax.legend()

# %%
fig.savefig('C:/Users/ASUS/OneDrive/桌面/实验报告/黑体辐射实验曲线.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
b = constants.Wien

# %%
1/data_T
# Out:
# array([0.00282606, 0.00286738, 0.00290994, 0.0029529 , 0.00299805,
#        0.00304368, 0.00309167, 0.0031343 , 0.00319234, 0.00324307])

# %%
data =np.array([0.28,
0.251,
0.222,
0.201,
0.181,
0.159,
0.144,
0.129,
0.117,
0.11])
data_T = np.array([80.7,
75.6,
70.5,
65.5,
60.4,
55.4,
50.3,
45.9,
40.1,
35.2,
])
data_T = data_T + 273.15

# %%
b/data_T*1e6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19076/2820179812.py in <module>
# ----> 1 b/data_T*1e6
#
# NameError: name 'b' is not defined

# %%
fig, ax = plt.subplots(1,1,figsize=(4,3))
ax.plot(data_T,b/data_T)
ax.scatter(data_T,b/data_T
          )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19076/1887939256.py in <module>
#       1 fig, ax = plt.subplots(1,1,figsize=(4,3))
# ----> 2 ax.plot(data_T,b/data_T)
#       3 ax.scatter(data_T,b/data_T
#       4           )
#
# NameError: name 'b' is not defined

# %%
data1 = np.array([0.827,
0.838,
0.853,
0.87,
0.895,
0.928,
0.97,
1.032,
1.102,
1.2,
1.343,
1.557,
1.895,
2.46E+00,
3.400E+00,
4.68E+00,
5.23E+00])
data2 = np.arange(400, 60, -20)

# %%
data2
X = np.linspace(data2[0],data2[-1], 500)
m = 33551.1
n = 0.609666

# %%
ax.legend?

# %%
fig,ax = plt.subplots(1,1, figsize=(7,5))
ax.plot(data2, data1,label=u'实验数据')
ax.plot(X, m/X**2+n,color='red',label=u'拟合：$M_T \sim m/d^2 + n $ \n $R^2=0.9614$')
ax.set_xlabel(r'$d/\mathrm{mm}$',fontsize=18)
ax.set_ylabel(r'$M_T$',fontsize=18)
ax.grid()
ax.legend(loc=1,prop=chinese)
fig.savefig('C:/Users/ASUS/OneDrive/桌面/实验报告/黑体辐射/辐出强度与距离.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot(data2, data1)

# %%
h = constants.h
c = constants.c
k_B = constants.Boltzmann
λ_t = 1e-3
λ_b = 760 * 1e-9
def Plank(λ,T):
    return 2*h*c**2/λ**5/(np.exp(h*c/(λ*k_B*T))-1)
def B(Ts):
    result = []
    for T in Ts:
        result.append(integrate.quad(Plank,λ_b, λ_t,args=T)[0])
    return np.array(result)

# %%
# %pylab

plot(data_T, data)
plot(data_T, B(data_T)*1e-3)
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
B(data_T)
# Out:
# array([282.96791049, 267.00364358, 251.72459249, 237.39113739,
#        223.41065585, 210.31289835, 197.55524128, 187.02292706,
#        173.78971041, 163.16817261])

# %%
data_T
# Out:
# array([353.85, 348.75, 343.65, 338.65, 333.55, 328.55, 323.45, 319.05,
#        313.25, 308.35])

# %%
data
# Out:
# array([0.28 , 0.251, 0.222, 0.201, 0.181, 0.159, 0.144, 0.129, 0.117,
#        0.11 ])

# %%
final_data = np.array([
    0.323,
0.288,
0.267,
0.235,
0.21,
0.188,
0.165,
0.145,
0.128,
0.112,

])
final_T = np.arange(80,30,-5) + 273.15
p = 3.2331*1e-11
q = -0.184727
x = np.linspace(final_T[0],final_T[-1], 1000)
chinese = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\simkai.ttf',size=18)

# %%
fig, ax = plt.subplots(1,1, figsize=(7,5))
ax.plot(final_T,final_data,label=u'实验数据')
ax.plot(x, p*x**4+q,label=u'拟合：$M_T \sim pT^4+q$ \n $R^2=0.9976$',color='red')
ax.grid()
ax.set_xlabel(r'T/$\mathrm{K}$',fontsize=18)
ax.set_ylabel(u'$M_T$',fontsize=18)
ax.legend(prop=chinese)

# %%
fig.savefig('C:/Users/ASUS/OneDrive/桌面/实验报告/黑体温度与辐出强度.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
